# %%
#함수 기초(functio  Basics)
-함수 : 특정 직업을 수행하는 코드의 묶음, 한 번 정의하면 언제든 재사용 가능하다.

# %%
#가장 기본적인 함수 정의와 호출 예시
def basic_function():
    print("Hello World!")

# %%
#개변수(Parameter)와 인자(Argument)
-매개변수: 함수 선언부의 변수 (공간) -매개인자: 함수 호출부에서 전달하는 값 (실체)

# %%
def add(a,b):                         # a,b 가 parameter
  print(f'a= {a}, b= {b}')
  return a+b

print (f'결과1: { add(10,20)}')       # 10,20이 argument
print (f'결과2: { add('Hello', 'World'})

# %%
def test(a,b):
    print(f'a={a}, b={b}')

test(10,20)
test(b=200, a=100)
test(10,b=10)

# %%
def greeting(name, greet='처음 뵙겠습니다')



greeting('다람쥐')
greeting('호랑이', '안녕?')

# %%
def calc(a,b):
    return a+b
