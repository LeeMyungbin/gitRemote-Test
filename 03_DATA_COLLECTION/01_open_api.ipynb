# %% [markdown]
# # OpenAPI 를 이용한 데이터 수집
#
# ## API (Application Programming Interface)
# - 프로그램과 프로그램이 서로 데이터를 주고 받기 위한 규칙
#
# ## Open API
# - 외부 개발자가 사용할 수 있도록 공개된 API
# - HTTP 기반 요청
# - JSON or XML 형태의 응답
# - API Key 필요 (서버 측 요청량 조절)

# %% [markdown]
# ## 환경변수 관리
# - 애플리케이션의 Client ID, Client Secret 값은 절대 외부에 노출 되어서는 안된다.
# - doienv 를 통해 관리할 수 있다.

# %%
# 셀 매직 명령어(%)로 python-dotenv 설치
# %pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# .env의 내용을 읽어서 환경 변수로 등록 처리
from dotenv import load_dotenv
load_dotenv()    # true가 나오면 .env 파일이 정상 로드 된 것
# Out:
# True

# %%
# 환경 변수로 등록 된 클라이언트 아이디와 시크릿 키를 읽어서 변수에 저장
import os

NAVER_CLIENT_ID = os.getenv('NAVER_CLIENT_ID')
NAVER_CLIENT_SECRET = os.getenv('NAVER_CLIENT_SECRET')

# %% [markdown]
# ## API 요청
# - 네이버 Documents 에서 API의 요청, 응답 규칙 확인 후 예제 수행

# %%
# 네이버 검색 API 예제 - 뉴스 검색
import os
import sys
import urllib.request
client_id = NAVER_CLIENT_ID
client_secret = NAVER_CLIENT_SECRET
encText = urllib.parse.quote("인공지능")
url = "https://openapi.naver.com/v1/search/news?display=20&query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 13 Mar 2026 10:25:16 +0900",
# 	"total":3767266,
# 	"start":1,
# 	"display":18,
# 	"items":[
# 		{
# 			"title":"증평군, 한국교원대와 에듀테크 교육 확대",
# 			"originallink":"https:\/\/www.ccdailynews.com\/news\/articleView.html?idxno=2402919",
# 			"link":"https:\/\/www.ccdailynews.com\/news\/articleView.html?idxno=2402919",
# 			"description":"참가자들은 <b>인공지능<\/b>(AI)과 디지털 기술 기반의 다양한 교육 콘텐츠를 직접 체험하며 새로운 학습 방식을 경험할 수 있을 전망이다. 또 오는 4월 18일에는 에듀테크 체험 부스와 원데이 클래스가 결합된 특별 프로그램도... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:24:00 +0900"
# 		},
# 		{
# 			"title":"&quot;네일 받고 피 철철&quot; AI사진으로 돈 뜯으려던 20대 외국인 송치",
# 			"originallink":"https:\/\/www.nocutnews.co.kr\/news\/6484324?utm_source=naver&utm_medium=article&utm_campaign=20260313102259",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/079\/0004124404?sid=102",
# 			"description":"창원중부경찰서는 <b>인공지능<\/b> 도구를 사용해 네일아트 시술 부작용이 생긴 것처럼 사진과 진료확인서를 조작한 뒤 업체에 돈을 뜯어내려 한 혐의(사기미수 등)20대 외국인 A씨를 송치했다고 13일 밝혔다. A씨는 지난해... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:23:00 +0900"
# 		},
# 		{
# 			"title":"[단독] 한투파, 칩스앤미디어 매각 시동…'볼트온 M&amp;A'도 추진",
# 			"originallink":"https:\/\/www.bloter.net\/news\/articleView.html?idxno=656562",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/293\/0000080850?sid=101",
# 			"description":"온디바이스 AI(<b>인공지능<\/b>)와 데이터센터 AI 가속기 시장이 확대되는 가운데 IP 공급 기업의 경우 고객사 확보가 성장 모멘텀과 직결될 수 있기 때문이다. 팹리스 업계 관계자는 &quot;반도체 산업에서 IP 기업은 설계 생태계의... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:23:00 +0900"
# 		},
# 		{
# 			"title":"삼성중공업, 美에 공동 연구 거점 구축…'마스가' 출발점",
# 			"originallink":"https:\/\/www.news1.kr\/industry\/general-industry\/6100154",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/421\/0008824037?sid=101",
# 			"description":"삼성중공업은 이 SSAM 센터를 거점으로 SDSU와 나스코 등과 협력해 <b>인공지능<\/b>(AI) 기반 생산 자동화와 로보틱스, 친환경 선박 기술 등 분야에서 공동 연구를 추진할 계획이다. 아울러 미국 내 대학과 정부 기관... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:23:00 +0900"
# 		},
# 		{
# 			"title":"[Telecom &amp; Now] kt m&amp;s, 자체 AI 플랫폼 'NEXUS'로 중소기업 지원",
# 			"originallink":"https:\/\/www.ebn.co.kr\/news\/articleView.html?idxno=1702333",
# 			"link":"https:\/\/www.ebn.co.kr\/news\/articleView.html?idxno=1702333",
# 			"description":"KT의 통신상품 유통 전문 그룹사 kt m&amp;s가 정부의 '2026 AI바우처 지원사업' 공급기업으로 선정되며 중소기업과 소상공인을 대상으로 <b>인공지능<\/b>(AI) 전환 지원에 나선다. kt m&amp;s는 자체 개발한 업무 통합 AI 플랫폼 'NEXUS... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"AI 번역 케이스냅, 30억 언어권 품고 K콘텐츠 영토 확장",
# 			"originallink":"https:\/\/www.econovill.com\/news\/articleView.html?idxno=733041",
# 			"link":"https:\/\/www.econovill.com\/news\/articleView.html?idxno=733041",
# 			"description":"헥토그룹 계열사 헥토미디어가 운영하는 <b>인공지능<\/b> 기반 K컬처 다국어 서비스 케이스냅이 중국어와 포르투갈어 서비스를 새롭게 도입하며 글로벌 이용자 확대에 나선다고 13일 밝혔다. 케이스냅은 기존 한국어 영어... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"NC AI, '바르코 게임 AI' 기반 모바일 게임 제작 선순환 생태계 구축",
# 			"originallink":"https:\/\/www.getnews.co.kr\/news\/articleView.html?idxno=864282",
# 			"link":"https:\/\/www.getnews.co.kr\/news\/articleView.html?idxno=864282",
# 			"description":"NC AI는 바르코 게임 <b>인공지능<\/b>(AI) 서비스를 기반으로 게임 제작부터 시장 검증, 퍼블리싱까지 이어지는 게임 제작 선순환 생태계 구축 전략을 추진한다고 13일 밝혔다. 이번 전략의 핵심은 중소 개발사의 제작 효율을... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"李대통령 “석유 최고가격제 위반 주유소 발견하면 신고해달라”",
# 			"originallink":"https:\/\/www.kukinews.com\/article\/view\/kuk202603130048",
# 			"link":"https:\/\/www.kukinews.com\/article\/view\/kuk202603130048",
# 			"description":"한편 이 대통령은 같은 날 과학기술정보통신부와 산업통상자원부, 중소벤처기업부가 올해 주요 <b>인공지능<\/b> 전환(AX) 사업을 통합 공고하고 기업 대상 설명회를 개최하기로 했다는 소식을 엑스에 공유하며 “부처 간... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"토종 AI 동맹, 네이버클라우드-코난 방산 제조 <b>지능<\/b>화 승부수",
# 			"originallink":"https:\/\/www.econovill.com\/news\/articleView.html?idxno=733042",
# 			"link":"https:\/\/www.econovill.com\/news\/articleView.html?idxno=733042",
# 			"description":"네이버클라우드가 <b>인공지능<\/b> 소프트웨어 전문기업 코난테크놀로지와 국방 제조 특화 거대언어모델 및 피지컬 AI 협력을 위한 업무협약을 체결하고 생성형 AI 생태계 확장에 나선다고 13일 밝혔다. 오픈AI, 마이크로소프트... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"크래프톤-한화에어로스페이스, '피지컬 AI' 협업해 합작사 설립",
# 			"originallink":"https:\/\/www.businesspost.co.kr\/BP?command=article_view&num=432786",
# 			"link":"https:\/\/www.businesspost.co.kr\/BP?command=article_view&num=432786",
# 			"description":"크래프톤은 한화에어로스페이스와 '피지컬 <b>인공지능<\/b>(AI)' 분야의 전략적 동맹을 구축하고 방위산업을 비롯한 다양한 영역에서 AI 기술 공동개발, 사업화를 추진한다고 13일 밝혔다. 체결된 업무협약(MOU)에 따라 두... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"버즈니 “AI 회의록 가장 많이 쓰는 업종은 IT·AI”",
# 			"originallink":"https:\/\/www.etnews.com\/20260313000074",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/030\/0003407215?sid=101",
# 			"description":"버즈니는 '정보통신(IT)·<b>인공지능<\/b>(AI) 업계'가 자사 AI 회의록 서비스를 가장 많이 이용하는 업종으로 조사됐“다고 13일 밝혔다. AI 회의록은 버튼 하나로 회의를 녹음하면 <b>인공지능<\/b>(AI)이 자동으로 회의 내용을 요약... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"한화에어로-크래프톤, 피지컬 AI 공동개발 '맞손'",
# 			"originallink":"https:\/\/it.chosun.com\/news\/articleView.html?idxno=2023092158569",
# 			"link":"https:\/\/it.chosun.com\/news\/articleView.html?idxno=2023092158569",
# 			"description":"한화에어로스페이스가 게임 '배틀그라운드' 제작사인 크래프톤과 '피지컬 <b>인공지능<\/b>'(Physical AI)을 공동 개발한다. 한화에어로스페이스는 크래프톤과 'AI 기술 공동 개발과 합작법인(Joint Venture) 설립 등을 위한 업무협약... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:22:00 +0900"
# 		},
# 		{
# 			"title":"아모레퍼시픽, 챗GPT에 '아모레몰' 앱 출시",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/AKR20260313062300030?input=1195m",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/001\/0015956803?sid=101",
# 			"description":"아모레퍼시픽은 <b>인공지능<\/b> 서비스 챗GPT에 자사 쇼핑 플랫폼 '아모레몰' 앱을 출시했다고 밝혔다. 이는 국내 뷰티 업계 최초로 챗GPT 앱을 선보인 것으로, 전 세계 챗GPT 사용자들이 대화 중 아모레퍼시픽의 제품을... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:21:00 +0900"
# 		},
# 		{
# 			"title":"위세아이텍, 문서 정보 추출 자동화 'iDocu' 베타 서비스 오픈",
# 			"originallink":"https:\/\/www.newsis.com\/view\/NISX20260313_0003546933",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/003\/0013819886?sid=101",
# 			"description":"AI(<b>인공지능<\/b>)·데이터 플랫폼 기업 위세아이텍은 무역 문서 정보 추출 자동화 서비스 'iDocu(아이다큐)'의 베타 서비스를 오픈했다고 13일 밝혔다. 회사 측에 따르면 아이다큐는 현재 시범운영사를 통해 실제 업무... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:21:00 +0900"
# 		},
# 		{
# 			"title":"아모레퍼시픽, 챗GPT에 '아모레몰' 앱 출시…&quot;AI 쇼핑 경험 제공&quot;",
# 			"originallink":"https:\/\/www.newspim.com\/news\/view\/20260313000334",
# 			"link":"https:\/\/www.newspim.com\/news\/view\/20260313000334",
# 			"description":"아모레퍼시픽이 국내 뷰티 업계 최초로 오픈AI의 챗CPT(ChatGPT)앱 개설을 통해 국내외 고객에게 <b>인공지능<\/b>(AI) 기반 뷰티 쇼핑 경험을 제공한다. 아모레퍼시픽은 챗GPT에 '아모레몰' 앱을 출시했다고 13일 밝혔다.... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:21:00 +0900"
# 		},
# 		{
# 			"title":"TSMC, 작년 시장 점유율 69.9%…삼성과 격차 더 벌렸다",
# 			"originallink":"https:\/\/www.kmib.co.kr\/article\/view.asp?arcid=0029521169&code=61141111&cp=nv",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/005\/0001836948?sid=101",
# 			"description":"<b>인공지능<\/b>(AI) 서버용 그래픽처리장치(GPU)와 구글의 텐서프로세서(TPU) 등 첨단 공정에 대한 수요가 폭발하면서 매출 성장을 견인했다. 전년 대비 매출 성장률은 36.1%에 달해 주요 업체 중 가장 높은 성장률을... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:21:00 +0900"
# 		},
# 		{
# 			"title":"李대통령 “석유 최고가격제 위반 주유소, 즉시 제게 신고해달라”",
# 			"originallink":"https:\/\/www.ddaily.co.kr\/page\/view\/2026031310201769691",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/138\/0002220481?sid=101",
# 			"description":"5원, 7.9원 내렸다. 이 대통령은 이날 석유 가격 대책과 함께 <b>인공지능<\/b> 전환(AX) 사업, 군 복무 기간의 국민연금 가입 인정 확대 등 정부 정책 등을 엑스를 통해 잇달아 소개하며 SNS 소통을 이어가는 모습이다.",
# 			"pubDate":"Fri, 13 Mar 2026 10:21:00 +0900"
# 		},
# 		{
# 			"title":"&quot;내 취향·의도 딱 아네?&quot;…네이버 쇼핑 AI 에이전트 써보니",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20260312175555",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002414216?sid=105",
# 			"description":"[편집자주] &quot;시간은 금이다.&quot; 누구나 아는 이 오래된 격언은 <b>인공지능<\/b>(AI)을 활용해 생산성을 높일 수 있는 요즘 같은 시대에 더 각광받는 속담이다. 많은 사람들이 AI를 단순 반복 작업이나 자료 조사 등에 활용하고 있지만... ",
# 			"pubDate":"Fri, 13 Mar 2026 10:21:00 +0900"
# 		}
# 	]
# }

# %%
## request 모듈을 사용한 요청으로 변경
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\Users\Playdata\miniconda3\envs\pystudy_env\Lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Playdata\miniconda3\envs\pystudy_env\Lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Playdata\miniconda3\envs\pystudy_env\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Playdata\miniconda3\envs\pystudy_env\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\Playdata\miniconda3\envs\pystudy_env\Lib\site-packages (from requests) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
# requests 모듈
import requests
import csv 
url = 'https://openapi.naver.com/v1/search/news.json'

headers = {
    "X-Naver-Client-Id" : NAVER_CLIENT_ID ,
    "X-Naver-Client-Secret" : NAVER_CLIENT_SECRET
}

# query string
params = {
    'query' : '인공지능',
    'display' : 10,              #10~100
    'start' : 1,
    'sort' : 'sim'              # sim or date
}

# 요청
response = requests.get(url, headers=headers, params=params)
print(f"HTTP Status Code: {response.status_code}")

# 결과 출력
if response.status_code == 200:
    # print(reponse.text)
    # response 객체는 json 문자열 형태로 응답이 돌아왔으므로 json() 메소드를 통해 dict로 변환
    data = response.json()
    print(data)

    # csv 파일로 저장하기
    with open('naver_news_인공지능.csv','w', encoding='utf-8', newline='') as f:
        # items 리스트의 첫 번째 요소의 키를 필드명으로 사용
        fieldnames = list(data['items'][0].keys())
        # csv 파일에 저장할 필드명 정의
        writer = csv.DictWriter(f, fieldnames= fieldnames)
        writer.writeheader()                      # 헤더 작성
        writer.writerows(data['items'])           # 데이터 작성

else:
    print("Error Code: {response.status_code}")
# Out:
# HTTP Status Code: 200
# {'lastBuildDate': 'Fri, 13 Mar 2026 10:30:28 +0900', 'total': 3767305, 'start': 1, 'display': 10, 'items': [{'title': '과기정통·산업·중기부, 4320억 규모 AI전환 사업 통합 공고', 'originallink': 'https://www.newsis.com/view/NISX20260312_0003545057', 'link': 'https://n.news.naver.com/mnews/article/003/0013817590?sid=105', 'description': '과학기술정보통신부, 산업통상자원부, 중소벤처기업부가 산업 <b>인공지능</b>(AI) 전문기업과 제조기업의 AI전환(AX) 사업 참여 환경 개선을 위해 공동 대응한다. 과기정통부와 산업부, 중기부는 올해 주요 AX 사업을 통합... ', 'pubDate': 'Thu, 12 Mar 2026 12:00:00 +0900'}, {'title': '이재명 대통령 “약속은 지킵니다”…‘국민주권정부’ 성과 알리기 나...', 'originallink': 'https://www.mk.co.kr/article/11987118', 'link': 'https://n.news.naver.com/mnews/article/009/0005649646?sid=100', 'description': '이 대통령은 과학기술정보통신부·산업통상자원부·중소벤처기업부가 4230억원대 <b>인공지능</b>(AI) 전환 사업 통합을 공고했다는 소식도 알렸다. 3개 부처는 주요 AI 전환 사업을 통합 공고하고 기업 대상 설명회를 개최할... ', 'pubDate': 'Fri, 13 Mar 2026 08:55:00 +0900'}, {'title': "AI 공포에 주가 40% 폭락…'18년 경력' CEO 물러난다", 'originallink': 'https://www.hankyung.com/article/202603138163i', 'link': 'https://n.news.naver.com/mnews/article/015/0005261889?sid=105', 'description': "테크 전문매체 디인포메이션은 “<b>인공지능</b>(AI)의 위협에 대응하기 위해 소프트웨어 기업이 경영진 개편에 나선 상징적인 사례”라고 분석했다. 'AI 공포'에 주가 40% 하락 나라옌 CEO는 12일(현지시간) “향후... ", 'pubDate': 'Fri, 13 Mar 2026 09:42:00 +0900'}, {'title': '한국서부발전, <b>인공지능</b> 활용 5명 체인지메이커 시상', 'originallink': 'http://www.fnnews.com/news/202603121624101321', 'link': 'https://n.news.naver.com/mnews/article/014/0005490589?sid=101', 'description': '특히 올해 시상식에서는 <b>인공지능</b>(AI) 기술을 기반으로 사회문제 해결에 나선 혁신 사례들이 다수 선정됐다. 디지털 재활 솔루션, 사고 자동 신고 시스템, 급식 복지 플랫폼 등 다양한 분야에서 기술 기반 사회혁신 모델이... ', 'pubDate': 'Thu, 12 Mar 2026 16:26:00 +0900'}, {'title': '과기정통부,‘<b>인공지능</b> 윤리원칙’ 제정 착수', 'originallink': 'https://www.dailian.co.kr/news/view/1620242/?sc=Naver', 'link': 'https://n.news.naver.com/mnews/article/119/0003068672?sid=105', 'description': '과학기술정보통신부는 13일 인스파이어 비즈센터 서울에서 ‘<b>인공지능</b> 윤리원칙’과 관련해 전문가 자문단을 발족했다. AI 윤리원칙은 AI가 사회에 미칠 수 있는 긍정적·부정적 영향을 고려해 인간 중심적이고 책임있는... ', 'pubDate': 'Fri, 13 Mar 2026 10:02:00 +0900'}, {'title': "'<b>인공지능</b> 윤리원칙' 제정에 속도 낸다... &quot;인간중심 AI개발·활용 촉진...", 'originallink': 'https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003214551&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news', 'link': 'https://n.news.naver.com/mnews/article/047/0002507918?sid=101', 'description': "▲  안전하고 신뢰할 수있는 <b>인공지능</b>(AI) 사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정 ⓒ omilaev on Unsplash 정부가 안전하고 신뢰할 수 있는 <b>인공지능</b>(AI)사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정에 본격 착수한다. AI가... ", 'pubDate': 'Fri, 13 Mar 2026 10:11:00 +0900'}, {'title': '원주, 의료 <b>인공지능</b>·반도체 발전 방안 모색', 'originallink': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8507431&ref=A', 'link': 'https://n.news.naver.com/mnews/article/056/0012141206?sid=101', 'description': '원주시는 어제(12일), 원주미래산업진흥원에서 의료 <b>인공지능</b>과 반도체 산업 육성을 위한 토론회를 개최했습니다. 이 자리에선 의료 분야 <b>인공지능</b>과 반도체 기술 확산 상황을 공유하고, 원주의 첨단 산업 육성 전략을... ', 'pubDate': 'Fri, 13 Mar 2026 08:33:00 +0900'}, {'title': "광주시, 경기도 최초 '<b>인공지능</b> 모자이크 CCTV' 민원실 도입", 'originallink': 'https://news.tf.co.kr/read/national/2301394.htm', 'link': 'https://n.news.naver.com/mnews/article/629/0000480612?sid=102', 'description': "경기 광주시는 민원실 내 안전 확보와 개인정보 보호 강화를 위해 경기도 민원실 가운데 최초로 '<b>인공지능</b>(AI) 모자이크 CC(폐쇄회로)TV'를 도입했다고 12일 밝혔다. 이번에 도입된 AI 모자이크 CCTV는 민원실 내 촬영... ", 'pubDate': 'Thu, 12 Mar 2026 11:16:00 +0900'}, {'title': "정부, '<b>인공지능</b> 고속도로 구축' 본격화…2조800억 투자", 'originallink': 'https://www.etoday.co.kr/news/view/2564810', 'link': 'https://www.etoday.co.kr/news/view/2564810', 'description': '이투데이=김연진 기자 | 과학기술정보통신부는 대한민국의 <b>인공지능</b>(AI) 생태계를 활성화하고 AI 3대 강국으로 도약하기 위한 핵심 인프라인 ‘AI 고속도로 구축’을 본격 추진한다고 12일 밝혔다. 이를 위해, 4월... ', 'pubDate': 'Thu, 12 Mar 2026 16:36:00 +0900'}, {'title': '청주대 조경학과, <b>인공지능</b> 접목 교육모델 도입', 'originallink': 'http://www.inews24.com/view/1948312', 'link': 'https://n.news.naver.com/mnews/article/031/0001012834?sid=102', 'description': '청주대학교(총장 김윤배)는 조경학과가 <b>인공지능</b>(AI)을 전공 교육에 접목한 교육 혁신 모델 ‘AI Triple Track’을 도입했 ...

# %% [markdown]
# ## json 데이터 형식을 xml 데이터 형식 응답으로 변경

# %%
# requests 모듈
import requests
url = 'https://openapi.naver.com/v1/search/news.xml'

headers = {
    "X-Naver-Client-Id" : NAVER_CLIENT_ID ,
    "X-Naver-Client-Secret" : NAVER_CLIENT_SECRET
}

# query string
params = {
    'query' : '인공지능',
    'display' : 10,              #10~100
    'start' : 1,
    'sort' : 'sim'              # sim or date
}

# 요청
response = requests.get(url, headers=headers, params=params)
print(f"HTTP Status Code: {response.status_code}")

# 결과 출력
if response.status_code == 200:
    print(response.text)

    # XML 파일로 저장 - response.content는 bytes 타입이므로 바이너리 모드로 파일을 열어서 저장한다.
    with open('naver_news_인공지능.xml', 'wb') as f:
        f.write(response.content)
        # xml extension 설치 후 alt+ shift + f

else:
    print("Error Code: {response.status_code}")
# Out:
# HTTP Status Code: 200
# <?xml version="1.0" encoding="UTF-8"?><rss version="2.0"><channel><title>Naver Open API - news ::&apos;인공지능&apos;</title><link>https://search.naver.com</link><description>Naver Search Result</description><lastBuildDate>Fri, 13 Mar 2026 10:43:24 +0900</lastBuildDate><total>3767386</total><start>1</start><display>10</display><item><title>과기정통·산업·중기부, 4320억 규모 AI전환 사업 통합 공고</title><originallink>https://www.newsis.com/view/NISX20260312_0003545057</originallink><link>https://n.news.naver.com/mnews/article/003/0013817590?sid=105</link><description>과학기술정보통신부, 산업통상자원부, 중소벤처기업부가 산업 &lt;b&gt;인공지능&lt;/b&gt;(AI) 전문기업과 제조기업의 AI전환(AX) 사업 참여 환경 개선을 위해 공동 대응한다. 과기정통부와 산업부, 중기부는 올해 주요 AX 사업을 통합... </description><pubDate>Thu, 12 Mar 2026 12:00:00 +0900</pubDate></item><item><title>이재명 대통령 “약속은 지킵니다”…‘국민주권정부’ 성과 알리기 나...</title><originallink>https://www.mk.co.kr/article/11987118</originallink><link>https://n.news.naver.com/mnews/article/009/0005649646?sid=100</link><description>이 대통령은 과학기술정보통신부·산업통상자원부·중소벤처기업부가 4230억원대 &lt;b&gt;인공지능&lt;/b&gt;(AI) 전환 사업 통합을 공고했다는 소식도 알렸다. 3개 부처는 주요 AI 전환 사업을 통합 공고하고 기업 대상 설명회를 개최할... </description><pubDate>Fri, 13 Mar 2026 08:55:00 +0900</pubDate></item><item><title>AI 공포에 주가 40% 폭락…&apos;18년 경력&apos; CEO 물러난다</title><originallink>https://www.hankyung.com/article/202603138163i</originallink><link>https://n.news.naver.com/mnews/article/015/0005261889?sid=105</link><description>테크 전문매체 디인포메이션은 “&lt;b&gt;인공지능&lt;/b&gt;(AI)의 위협에 대응하기 위해 소프트웨어 기업이 경영진 개편에 나선 상징적인 사례”라고 분석했다. &apos;AI 공포&apos;에 주가 40% 하락 나라옌 CEO는 12일(현지시간) “향후... </description><pubDate>Fri, 13 Mar 2026 09:42:00 +0900</pubDate></item><item><title>한국서부발전, &lt;b&gt;인공지능&lt;/b&gt; 활용 5명 체인지메이커 시상</title><originallink>http://www.fnnews.com/news/202603121624101321</originallink><link>https://n.news.naver.com/mnews/article/014/0005490589?sid=101</link><description>특히 올해 시상식에서는 &lt;b&gt;인공지능&lt;/b&gt;(AI) 기술을 기반으로 사회문제 해결에 나선 혁신 사례들이 다수 선정됐다. 디지털 재활 솔루션, 사고 자동 신고 시스템, 급식 복지 플랫폼 등 다양한 분야에서 기술 기반 사회혁신 모델이... </description><pubDate>Thu, 12 Mar 2026 16:26:00 +0900</pubDate></item><item><title>과기정통부,‘&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙’ 제정 착수</title><originallink>https://www.dailian.co.kr/news/view/1620242/?sc=Naver</originallink><link>https://n.news.naver.com/mnews/article/119/0003068672?sid=105</link><description>과학기술정보통신부는 13일 인스파이어 비즈센터 서울에서 ‘&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙’과 관련해 전문가 자문단을 발족했다. AI 윤리원칙은 AI가 사회에 미칠 수 있는 긍정적·부정적 영향을 고려해 인간 중심적이고 책임있는... </description><pubDate>Fri, 13 Mar 2026 10:02:00 +0900</pubDate></item><item><title>&apos;&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙&apos; 제정에 속도 낸다... &amp;quot;인간중심 AI개발·활용 촉진...</title><originallink>https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003214551&amp;CMPT_CD=P0010&amp;utm_source=naver&amp;utm_medium=newsearch&amp;utm_campaign=naver_news</originallink><link>https://n.news.naver.com/mnews/article/047/0002507918?sid=101</link><description>▲  안전하고 신뢰할 수있는 &lt;b&gt;인공지능&lt;/b&gt;(AI) 사회 구현을 위한 &apos;&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙&apos; 제정 ⓒ omilaev on Unsplash 정부가 안전하고 신뢰할 수 있는 &lt;b&gt;인공지능&lt;/b&gt;(AI)사회 구현을 위한 &apos;&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙&apos; 제정에 본격 착수한다. AI가... </description><pubDate>Fri, 13 Mar 2026 10:11:00 +0900</pubDate></item><item><title>원주, 의료 &lt;b&gt;인공지능&lt;/b&gt;·반도체 발전 방안 모색</title><originallink>https://news.kbs.co.kr/news/pc/view/view.do?ncd=8507431&amp;ref=A</originallink><link>https://n.news.naver.com/mnews/article/056/0012141206?sid=101</link><description>원주시는 어제(12일), 원주미래산업진흥원에서 의료 &lt;b&gt;인공지능&lt;/b&gt;과 반도체 산업 육성을 위한 토론회를 개최했습니다. 이 자리에선 의료 분야 &lt;b&gt;인공지능&lt;/b&gt;과 반도체 기술 확산 상황을 공유하고, 원주의 첨단 산업 육성 전략을... </description><pubDate>Fri, 13 Mar 2026 08:33:00 +0900</pubDate></item><item><title>&lt;b&gt;인공지능&lt;/b&gt;(AI)·발명과학·토론… 강동구, 미래인재 키운다</title><originallink>https://biz.heraldcorp.com/article/10693309?ref=naver</originallink><link>https://n.news.naver.com/mnews/article/016/0002612874?sid=102</link><description>4~6월 초등학생 대상 상반기 미래인재육성 프로그램 9개 과정 운영 &lt;b&gt;인공지능&lt;/b&gt;(AI) 코딩·자율주행 로봇· ...

# %% [markdown]
# ## 데이터 DB 저장하기
#
# ### 테이블/모델 설계

# %%
from dataclasses import dataclass
from datetime import datetime
from typing import Optional

@dataclass
class NaverNews:

    id : int
    title: str
    originallink: str
    link: str
    description: str
    pubDate: str
    created_at: Optional[datetime] = None

# %% [markdown]
# ## OpenAPI로 수집 된 데이터 DB 저장하기

# %%
# requests 모듈
import requests 
url = 'https://openapi.naver.com/v1/search/news.json'

headers = {
    "X-Naver-Client-Id" : NAVER_CLIENT_ID ,
    "X-Naver-Client-Secret" : NAVER_CLIENT_SECRET
}

# query string
params = {
    'query' : '인공지능',
    'display' : 10,              #10~100
    'start' : 1,
    'sort' : 'sim'              # sim or date
}

# 요청
response = requests.get(url, headers=headers, params=params)
naver_news_list: list[NaverNews]= []

# 결과 출력
if response.status_code == 200:
    data = response.json()    # dict 으로 변환
    items = data['items']
    for item in items:
        naver_news_list.append(NaverNews(None,**item))
    print(naver_news_list)
else:
    print("Error Code: {response.status_code}")
# Out:
# [NaverNews(id=None, title='과기정통·산업·중기부, 4320억 규모 AI전환 사업 통합 공고', originallink='https://www.newsis.com/view/NISX20260312_0003545057', link='https://n.news.naver.com/mnews/article/003/0013817590?sid=105', description='과학기술정보통신부, 산업통상자원부, 중소벤처기업부가 산업 <b>인공지능</b>(AI) 전문기업과 제조기업의 AI전환(AX) 사업 참여 환경 개선을 위해 공동 대응한다. 과기정통부와 산업부, 중기부는 올해 주요 AX 사업을 통합... ', pubDate='Thu, 12 Mar 2026 12:00:00 +0900', created_at=None), NaverNews(id=None, title="AI 공포에 주가 40% 폭락…'18년 경력' CEO 물러난다", originallink='https://www.hankyung.com/article/202603138163i', link='https://n.news.naver.com/mnews/article/015/0005261889?sid=105', description="테크 전문매체 디인포메이션은 “<b>인공지능</b>(AI)의 위협에 대응하기 위해 소프트웨어 기업이 경영진 개편에 나선 상징적인 사례”라고 분석했다. 'AI 공포'에 주가 40% 하락 나라옌 CEO는 12일(현지시간) “향후... ", pubDate='Fri, 13 Mar 2026 09:42:00 +0900', created_at=None), NaverNews(id=None, title='[단독]문체부, AI 콘텐츠산업 진흥법 제정 추진...문화<b>인공지능</b>정책과 ...', originallink='https://news.mtn.co.kr/news-detail/2026031310340012270', link='https://news.mtn.co.kr/news-detail/2026031310340012270', description='문화체육관광부가 문화<b>인공지능</b>정책과를 신설하고 <b>인공지능</b> 기반 콘텐츠산업 진흥법(가칭, 이하 AI 콘텐츠산업 진흥법) 제정 준비 작업을 본격화한다. 문체부는 지난해 한국콘텐츠진흥원을 통해 해당 법안 제정을 위한... ', pubDate='Fri, 13 Mar 2026 11:42:00 +0900', created_at=None), NaverNews(id=None, title='이재명 대통령 “약속은 지킵니다”…‘국민주권정부’ 성과 알리기 나...', originallink='https://www.mk.co.kr/article/11987118', link='https://n.news.naver.com/mnews/article/009/0005649646?sid=100', description='이 대통령은 과학기술정보통신부·산업통상자원부·중소벤처기업부가 4230억원대 <b>인공지능</b>(AI) 전환 사업 통합을 공고했다는 소식도 알렸다. 3개 부처는 주요 AI 전환 사업을 통합 공고하고 기업 대상 설명회를 개최할... ', pubDate='Fri, 13 Mar 2026 08:55:00 +0900', created_at=None), NaverNews(id=None, title='한국서부발전, <b>인공지능</b> 활용 5명 체인지메이커 시상', originallink='http://www.fnnews.com/news/202603121624101321', link='https://n.news.naver.com/mnews/article/014/0005490589?sid=101', description='특히 올해 시상식에서는 <b>인공지능</b>(AI) 기술을 기반으로 사회문제 해결에 나선 혁신 사례들이 다수 선정됐다. 디지털 재활 솔루션, 사고 자동 신고 시스템, 급식 복지 플랫폼 등 다양한 분야에서 기술 기반 사회혁신 모델이... ', pubDate='Thu, 12 Mar 2026 16:26:00 +0900', created_at=None), NaverNews(id=None, title='과기정통부,‘<b>인공지능</b> 윤리원칙’ 제정 착수', originallink='https://www.dailian.co.kr/news/view/1620242/?sc=Naver', link='https://n.news.naver.com/mnews/article/119/0003068672?sid=105', description='과학기술정보통신부는 13일 인스파이어 비즈센터 서울에서 ‘<b>인공지능</b> 윤리원칙’과 관련해 전문가 자문단을 발족했다. AI 윤리원칙은 AI가 사회에 미칠 수 있는 긍정적·부정적 영향을 고려해 인간 중심적이고 책임있는... ', pubDate='Fri, 13 Mar 2026 10:02:00 +0900', created_at=None), NaverNews(id=None, title="'<b>인공지능</b> 윤리원칙' 제정에 속도 낸다... &quot;인간중심 AI개발·활용 촉진...", originallink='https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003214551&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news', link='https://n.news.naver.com/mnews/article/047/0002507918?sid=101', description="▲  안전하고 신뢰할 수있는 <b>인공지능</b>(AI) 사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정 ⓒ omilaev on Unsplash 정부가 안전하고 신뢰할 수 있는 <b>인공지능</b>(AI)사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정에 본격 착수한다. AI가... ", pubDate='Fri, 13 Mar 2026 10:11:00 +0900', created_at=None), NaverNews(id=None, title='<b>인공지능</b>(AI)·발명과학·토론… 강동구, 미래인재 키운다', originallink='https://biz.heraldcorp.com/article/10693309?ref=naver', link='https://n.news.naver.com/mnews/article/016/0002612874?sid=102', description='4~6월 초등학생 대상 상반기 미래인재육성 프로그램 9개 과정 운영 <b>인공지능</b>(AI) 코딩·자율주행 로봇·짝 토론 등 놀이와 학습 결합해 흥미 높여 포스터 [헤럴드경제=박종일 선임기자]서울 강동구(구청장 이수희)는... ', pubDate='Fri, 13 Mar 2026 07:07:00 +0900', created_at=None), NaverNews(id=None, title='원주, 의료 <b>인공지능</b>·반도체 발전 방안 모색', originallink='https://news.kbs.co.kr/news/pc/view/view.do?ncd=8507431&ref=A', link='https://n.news.naver.com/mnews/article/056/0012141206?sid=101', description='원주시는 어제(12일), 원주미래산업진흥원에서 의료 <b>인공지능</b>과 반도체 산업 육성을 위한 토론회를 개최했습니다. 이 자리에선 의료 분야 <b>인공지능</b>과 반도체 기술 확산 상황을 공유하고, 원주의 첨단 산업 육성 전략을... ', pubDate='Fri, 13 Mar 2026 08:33:00 +0900', created_at=None), NaverNews(id=None, title="과기정통부, '<b>인공지능</b> 윤리원칙' 제정 착수…전문가 자문단 발족", originallink='https://www.etoday.co.kr/news/view/2564836', link='https://www.etoday.co.kr/new ...

# %%
import mysql.connector

config={
    "host": "localhost",
    "port": 3306,
    "user": "ohgiraffers"
    "password":"ohgiraffers"
    "database": "menudb"
}

with mysql.connector.connect(**config) as conn:
    with conn.cursor() as cursor:
        try:
            for naver_news in naver_news_list:
                sql = """ 
                insert into naver_news (title, originallink, link, description, pub_date)
                vlues (%s,%s,%s,%s,%s)
                """
                cursor.execute(
                    sql,
                    (naver_news.title,
                     naver_news.originallink,
                     naver_news.link,
                     naver_news.description,
                     naver_news.pubDate
                     )
                )

            conn.commit()
        except mysql.connector.Error as e:
            print("DB 오류 :", e)
# Out:
#   Cell In[9], line 7
#     "password":"ohgiraffers"
#               ^
# SyntaxError: invalid syntax
