# %% [markdown]
# # mysql-connector-python
# - Python 프로그램에서 MySQL 데이터베이스에 접속하고 SQL을 실행할 수 있게 해주는 라이브러리

# %%
# %pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\Users\Playdata\miniconda3\envs\pystudy_env\Lib\site-packages (9.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connection과 Cursor
# - Connection : DB 서버에 연결하는 객체
# - Cursor : 쿼리를 수행하고 결과를 가지고 있는 객체
# - 두 객체 모두 사용 후 반납 필수!!!

# %%
import mysql.connector

# DB 접속 정보를 전달하여 연결 객체 생성 후 반환
conn = mysql.connector.connect(
    host='localhost',
    port=3306,
    user='ohgiraffers',
    password='ohgiraffers',
    database='menudb'
)

# 연결 객체를 통해 커서 객체 생성
cursor = conn.cursor()

sql =""" 
select
     *
from
     tbl_menu
"""
cursor.execute(sql)           # 전달한 sql 구문 실행
rows = cursor.fetchall()      # 결과 집합 반환    (여러 행)
for row in rows:
    print(row)                # 한 행은 튜플 형태로 반환

# 연결 종료 (리소스 반환)
cursor.close()
conn.close()
# Out:
# (1, '참기름소주', 4500, 10, 'Y')
# (2, '우럭쥬스', 6000, 9, 'N')
# (3, '생갈치쉐이크', 6000, 10, 'Y')
# (4, '갈릭미역파르페', 7000, 10, 'Y')
# (5, '앙버터김치찜', 13000, 4, 'N')
# (6, '생마늘샐러드', 12000, 4, 'Y')
# (7, '민트미역국', 15000, 4, 'Y')
# (8, '한우딸기국밥', 20000, 4, 'Y')
# (9, '홍어마카롱', 9000, 12, 'Y')
# (10, '코다리마늘빵', 7000, 12, 'N')
# (11, '정어리빙수', 10000, 10, 'Y')
# (12, '날치알스크류바', 2000, 10, 'Y')
# (13, '직화구이젤라또', 8000, 12, 'Y')
# (14, '과메기커틀릿', 13000, 6, 'Y')
# (15, '죽방멸치튀김우동', 11000, 6, 'N')
# (16, '흑마늘아메리카노', 9000, 8, 'Y')
# (17, '아이스가리비관자육수', 6000, 10, 'Y')
# (18, '붕어빵초밥', 35000, 6, 'Y')
# (19, '까나리코코넛쥬스', 9000, 9, 'Y')
# (20, '마라깐쇼한라봉', 22000, 5, 'N')
# (21, '돌미나리백설기', 5000, 11, 'Y')
# (22, '초콜릿죽', 9500, 5, 'Y')
# (23, '초콜릿죽', 9500, 5, 'Y')
# (25, '참치맛아이스크림', 1700, 12, 'Y')
# (26, '멸치맛아이스크림', 1500, 12, 'Y')
# (27, '꽁치맛아이스크림', 1600, 12, 'Y')
# (28, '참치맛아이스크림', 1700, 12, 'Y')
# (31, '식혜맛국밥', 5500, 4, 'Y')
# (32, '수정과맛국밥', 6500, 4, 'Y')
# (33, '4번카테고리', 6500, 2, 'Y')
# (34, '5번카테고리', 6500, 5, 'Y')

# %% [markdown]
# ## Menu 클래스 정의 후 객체에 데이터 담기

# %%
# 데이터를 저장하는 목적의 클래스를 쉽게 만들도록 도와주는 기능으로
# 일반 클래스에선 __init__ , __repr__ 등을 직접 작성해야 하지만 자동으로 생성해준다.
from dataclasses import dataclass

# typing 모듈 타입 힌트를 작성할 때 사용하는 도구 제공
from typing import Optional

@dataclass
class Menu:

    menu_code: int
    menu_name: str
    menu_price: int
    # int 또는 None이 들어올 수 있다는 의미
    category_code: Optional[int]
    orderable: str

# %%
# Menu 인스턴스에 조회 된 데이터 담기
db_config = {
    "host": "localhost",
    "port": 3306,
    "user": "ohgiraffers",
    "password": "ohgiraffers",
    "database": "menudb"
}

# 인스턴스를 담을 리스트
menus = []

with mysql.connector.connect(**db_config) as conn:
    with conn.cursor() as cursor:
        cursor.execute("select * from tbl_menu")
        rows = cursor.fetchall()
        for row in rows:
            menus.append(Menu(*row))

# 메뉴 리스트 출력
menus
# Out:
# [Menu(menu_code=1, menu_name='참기름소주', menu_price=4500, category_code=10, orderable='Y'),
#  Menu(menu_code=2, menu_name='우럭쥬스', menu_price=6000, category_code=9, orderable='N'),
#  Menu(menu_code=3, menu_name='생갈치쉐이크', menu_price=6000, category_code=10, orderable='Y'),
#  Menu(menu_code=4, menu_name='갈릭미역파르페', menu_price=7000, category_code=10, orderable='Y'),
#  Menu(menu_code=5, menu_name='앙버터김치찜', menu_price=13000, category_code=4, orderable='N'),
#  Menu(menu_code=6, menu_name='생마늘샐러드', menu_price=12000, category_code=4, orderable='Y'),
#  Menu(menu_code=7, menu_name='민트미역국', menu_price=15000, category_code=4, orderable='Y'),
#  Menu(menu_code=8, menu_name='한우딸기국밥', menu_price=20000, category_code=4, orderable='Y'),
#  Menu(menu_code=9, menu_name='홍어마카롱', menu_price=9000, category_code=12, orderable='Y'),
#  Menu(menu_code=10, menu_name='코다리마늘빵', menu_price=7000, category_code=12, orderable='N'),
#  Menu(menu_code=11, menu_name='정어리빙수', menu_price=10000, category_code=10, orderable='Y'),
#  Menu(menu_code=12, menu_name='날치알스크류바', menu_price=2000, category_code=10, orderable='Y'),
#  Menu(menu_code=13, menu_name='직화구이젤라또', menu_price=8000, category_code=12, orderable='Y'),
#  Menu(menu_code=14, menu_name='과메기커틀릿', menu_price=13000, category_code=6, orderable='Y'),
#  Menu(menu_code=15, menu_name='죽방멸치튀김우동', menu_price=11000, category_code=6, orderable='N'),
#  Menu(menu_code=16, menu_name='흑마늘아메리카노', menu_price=9000, category_code=8, orderable='Y'),
#  Menu(menu_code=17, menu_name='아이스가리비관자육수', menu_price=6000, category_code=10, orderable='Y'),
#  Menu(menu_code=18, menu_name='붕어빵초밥', menu_price=35000, category_code=6, orderable='Y'),
#  Menu(menu_code=19, menu_name='까나리코코넛쥬스', menu_price=9000, category_code=9, orderable='Y'),
#  Menu(menu_code=20, menu_name='마라깐쇼한라봉', menu_price=22000, category_code=5, orderable='N'),
#  Menu(menu_code=21, menu_name='돌미나리백설기', menu_price=5000, category_code=11, orderable='Y'),
#  Menu(menu_code=22, menu_name='초콜릿죽', menu_price=9500, category_code=5, orderable='Y'),
#  Menu(menu_code=23, menu_name='초콜릿죽', menu_price=9500, category_code=5, orderable='Y'),
#  Menu(menu_code=25, menu_name='참치맛아이스크림', menu_price=1700, category_code=12, orderable='Y'),
#  Menu(menu_code=26, menu_name='멸치맛아이스크림', menu_price=1500, category_code=12, orderable='Y'),
#  Menu(menu_code=27, menu_name='꽁치맛아이스크림', menu_price=1600, category_code=12, orderable='Y'),
#  Menu(menu_code=28, menu_name='참치맛아이스크림', menu_price=1700, category_code=12, orderable='Y'),
#  Menu(menu_code=31, menu_name='식혜맛국밥', menu_price=5500, category_code=4, orderable='Y'),
#  Menu(menu_code=32, menu_name='수정과맛국밥', menu_price=6500, category_code=4, orderable='Y'),
#  Menu(menu_code=33, menu_name='4번카테고리', menu_price=6500, category_code=2, orderable='Y'),
#  Menu(menu_code=34, menu_name='5번카테고리', menu_price=6500, category_code=5, orderable='Y')]

# %% [markdown]
# ## 한 건 조회 (메뉴 코드)

# %%
try:
    with mysql.connector.connect(**db_config) as conn:
        with conn.cursor() as cursor:
            sql =""" 
                select
                     *
                from
                    tbl_menu
                where
                    menu_code= %s
                """
            cursor.execute(sql, (1,))   # sql, params
            row = cursor.fetchone()
            print(Menu(*row))


except mysql.connector.Error as e:
    print('DB 오류:', e)
# Out:
# Menu(menu_code=1, menu_name='참기름소주', menu_price=4500, category_code=10, orderable='Y')

# %% [markdown]
# ## 여러 건 조회 (메뉴 이름 키워드 포함)

# %%
try:
    with mysql.connector.connect(**db_config) as conn:
        with conn.cursor() as cursor:
            sql =""" 
                select
                     *
                from
                    tbl_menu
                where
                    menu_name like concat('%', %s,'%')
                """
            cursor.execute(sql, ('마늘',))   # sql, params
            menus = [Menu(*row) for row in cursor.fetchall()]
            print(menus)
        
        
except mysql.connector.Error as e:
    print('DB 오류:', e)
# Out:
# [Menu(menu_code=6, menu_name='생마늘샐러드', menu_price=12000, category_code=4, orderable='Y'), Menu(menu_code=10, menu_name='코다리마늘빵', menu_price=7000, category_code=12, orderable='N'), Menu(menu_code=16, menu_name='흑마늘아메리카노', menu_price=9000, category_code=8, orderable='Y')]

# %% [markdown]
# ## 레코드 추가

# %%
menu = Menu(None, '요거트엑젓' , 20_000, 8, 'Y')

try:
    with mysql.connector.connect(**db_config) as conn:
        with conn.cursor() as cursor:
             sql =""" 
                insert into tbl_menu (menu_name, menu_price, category_code, orderable_status)
                values(%s, %s, %s, %s)
                """
             cursor.execute(
                    sql, 
                   (menu.menu_name, menu_price, menu.category_code, menu.orderable_status)
                )   # sql, params
             print(cursor.rowcount, '개 행이 삽입 되었습니다') # rowcount : DML을 통해 변경 된 행의 개수
             conn.commit()   # autocommit이 아니므로 명시적 commit 호출
        
        
except mysql.connector.Error as e:
    print('DB 오류:', e)

# %% [markdown]
# ## 레코드 수정
# - 삽입 했던 행의 메뉴 코드를 이용해서 메뉴명 수정하기

# %%
menu_code = 24
new_menu_name = '울트라요거트액젓'
try:
    with mysql.connector.connect(**db_config) as conn:
        with conn.cursor() as cursor:
             sql =""" 
                 update
                """
             cursor.execute(
                    sql, 
                   (menu.menu_name, menu_price, menu.category_code, menu.orderable_status)
                )   # sql, params
             print(cursor.rowcount, '개 행이 삽입 되었습니다') # rowcount : DML을 통해 변경 된 행의 개수
             conn.commit()   # autocommit이 아니므로 명시적 commit 호출

# %% [markdown]
# ## 레코드 삭제
# - 삽입 했던 행의 메뉴 코드를 이용해서 행 삭제

# %%
menu_code = 34
try:
    with mysql.connector.connect(**db_config) as conn:
        with conn.cursor() as cursor:
             sql =""" 
                delete from
                    tbl_menu
                where
                    menu_code = %s
                """
             cursor.execute(
                    sql, 
                   (menu_code)
                )  
             print(cursor.rowcount, '개 행이 삽입 되었습니다') 
             conn.commit()  
except mysql.connector.Error as e:
    print('DB 오류:', e)
