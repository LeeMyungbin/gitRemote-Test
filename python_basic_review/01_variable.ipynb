# %% [markdown]
# # 변수이릅 규칙
# 1. 의미있는 이름 사용 (직관적인)
# 2. 소문자와 밑줄 사용
# 3. 너무 길거나 짧지 않게 시용
# 4. 한글은 가능하나 권장 X
# 5. 숫자로 시작 X
# 6. 공백 사용 X
# 7. pyton 예약어 사용 X (if, for while...)
# 8. 대소문자 구분
# 9. _를 제외한 특수문자 사용 불가
