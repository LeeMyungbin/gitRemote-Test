# %% [markdown]
# # Pandas practice 1
# - 온라인 쇼핑몰 주문 데이터를 다루는 실습이다.
# - 범위:intro, indexing_edit, io, preprocessing

# %%
import pandas as pd
import numpy as np

orders = pd.DataFrame({
    '주문번호': ['O001', 'O002', 'O003', 'O004', 'O005', 'O006', 'O006', 'O008'],
    '주문일자': ['2026-01-03', '2026-01-05', '2026-01-05', '2026-01-08', '2026-01-10', '2026-01-12', '2026-01-12', '2026-01-15'],
    '고객명': ['김철수', '이영희', '박민수', '최지영', '정다은', '홍길동', '홍길동', '강민호'],
    '지역': ['서울', '부산', '서울', '대전', None, '부산', '부산', '서울'],
    '카테고리': ['전자', '식품', '전자', '패션', '식품', '전자', '전자', '패션'],
    '상품명': ['노트북', '사과', '마우스', '자켓', '우유', '키보드', '키보드', '운동화'],
    '수량': [1, 10, 2, 1, np.nan, 1, 1, 2],
    '단가': [1500000, 3000, 25000, 120000, 2500, 50000, 50000, 90000],
    '결제상태': ['완료', '완료', '완료', '취소', '완료', '완료', '완료', '완료']
})
orders
# Out:
#    주문번호        주문일자  고객명   지역 카테고리  상품명    수량       단가 결제상태
# 0  O001  2026-01-03  김철수   서울   전자  노트북   1.0  1500000   완료
# 1  O002  2026-01-05  이영희   부산   식품   사과  10.0     3000   완료
# 2  O003  2026-01-05  박민수   서울   전자  마우스   2.0    25000   완료
# 3  O004  2026-01-08  최지영   대전   패션   자켓   1.0   120000   취소
# 4  O005  2026-01-10  정다은  NaN   식품   우유   NaN     2500   완료
# 5  O006  2026-01-12  홍길동   부산   전자  키보드   1.0    50000   완료
# 6  O006  2026-01-12  홍길동   부산   전자  키보드   1.0    50000   완료
# 7  O008  2026-01-15  강민호   서울   패션  운동화   2.0    90000   완료

# %% [markdown]
# ## 1. 기본 확인
# 1. orders의 shape를 확인하시오.
# 2. columns를 확인하시오.
# 3. 상위 3행을 확인하시오.

# %%
print(f"shape: {orders.shape}")
print(f"columns: {orders.columns}")
print(orders.head(3))
# Out:
# shape: (8, 9)
# columns: Index(['주문번호', '주문일자', '고객명', '지역', '카테고리', '상품명', '수량', '단가', '결제상태'], dtype='str')
#    주문번호        주문일자  고객명  지역 카테고리  상품명    수량       단가 결제상태
# 0  O001  2026-01-03  김철수  서울   전자  노트북   1.0  1500000   완료
# 1  O002  2026-01-05  이영희  부산   식품   사과  10.0     3000   완료
# 2  O003  2026-01-05  박민수  서울   전자  마우스   2.0    25000   완료

# %% [markdown]
# ## 2. 열 선택
# 1. 고객명 열만 선택하시오.
# 2. 상품명, 수량, 단가 열만 선택하시오.

# %%
print(orders["고객명"])   
print(orders[["상품명", "수량", "단가"]]) 

# 정답 : display(orders[["상품명", "수량", "단가"]])
# Out:
# 0    김철수
# 1    이영희
# 2    박민수
# 3    최지영
# 4    정다은
# 5    홍길동
# 6    홍길동
# 7    강민호
# Name: 고객명, dtype: str
#    상품명    수량       단가
# 0  노트북   1.0  1500000
# 1   사과  10.0     3000
# 2  마우스   2.0    25000
# 3   자켓   1.0   120000
# 4   우유   NaN     2500
# 5  키보드   1.0    50000
# 6  키보드   1.0    50000
# 7  운동화   2.0    90000

# %% [markdown]
# ## 3.인덱싱
# - 주문번호를 인덱스로 설정한 새로운 DataFrame df를 만들고 아래를 수행하시오.
# 1. O003 행 전체를 loc으로 조회
# 2. 첫 번째 행을 iloc으로 조회
# 3. O002의 단가를 at으로 조회

# %%
num = pd.DataFrame({
    '주문일자': ['2026-01-03', '2026-01-05', '2026-01-05', '2026-01-08', '2026-01-10', '2026-01-12', '2026-01-12', '2026-01-15'],
    '고객명': ['김철수', '이영희', '박민수', '최지영', '정다은', '홍길동', '홍길동', '강민호'],
    '지역': ['서울', '부산', '서울', '대전', None, '부산', '부산', '서울'],
    '카테고리': ['전자', '식품', '전자', '패션', '식품', '전자', '전자', '패션'],
    '상품명': ['노트북', '사과', '마우스', '자켓', '우유', '키보드', '키보드', '운동화'],
    '수량': [1, 10, 2, 1, np.nan, 1, 1, 2],
    '단가': [1500000, 3000, 25000, 120000, 2500, 50000, 50000, 90000],
    '결제상태': ['완료', '완료', '완료', '취소', '완료', '완료', '완료', '완료']
}, index = ['O001', 'O002', 'O003', 'O004', 'O005', 'O006', 'O006', 'O008'])
# 정답 : df = orders.set_index('주문번호')

print(num.loc["O003"]) 
print(num.iloc[0]) 
print(num.at['O002','단가'])
# Out:
# 주문일자    2026-01-05
# 고객명            박민수
# 지역              서울
# 카테고리            전자
# 상품명            마우스
# 수량             2.0
# 단가           25000
# 결제상태            완료
# Name: O003, dtype: object
# 주문일자    2026-01-03
# 고객명            김철수
# 지역              서울
# 카테고리            전자
# 상품명            노트북
# 수량             1.0
# 단가         1500000
# 결제상태            완료
# Name: O001, dtype: object
# 3000

# %% [markdown]
# ## 4. 조건 필터링
# 1. 결제상태가 완료인 행만 조회하시오.
# 2. 카테고리가 전자이고 단가가 30000 이상인 행만 조회하시오.
# 3. 지역이 서울 또는 부산인 행만 조회하시오.

# %%
print(orders[orders['결제상태'] == '완료'])
print(orders[(orders['카테고리'] == '전자') & orders['단가'] >= 30000])
print(orders[(orders['지역'] == '서울') | orders['지역'] == '부산'])

# 정답 : display(orders[orders['지역'].isin(['서울','부산'])])
# Out:
#    주문번호        주문일자  고객명   지역 카테고리  상품명    수량       단가 결제상태
# 0  O001  2026-01-03  김철수   서울   전자  노트북   1.0  1500000   완료
# 1  O002  2026-01-05  이영희   부산   식품   사과  10.0     3000   완료
# 2  O003  2026-01-05  박민수   서울   전자  마우스   2.0    25000   완료
# 4  O005  2026-01-10  정다은  NaN   식품   우유   NaN     2500   완료
# 5  O006  2026-01-12  홍길동   부산   전자  키보드   1.0    50000   완료
# 6  O006  2026-01-12  홍길동   부산   전자  키보드   1.0    50000   완료
# 7  O008  2026-01-15  강민호   서울   패션  운동화   2.0    90000   완료
# Empty DataFrame
# Columns: [주문번호, 주문일자, 고객명, 지역, 카테고리, 상품명, 수량, 단가, 결제상태]
# Index: []
# Empty DataFrame
# Columns: [주문번호, 주문일자, 고객명, 지역, 카테고리, 상품명, 수량, 단가, 결제상태]
# Index: []
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_17432\3145929123.py:3: Pandas4Warning: 'or' operations between boolean dtype and str are deprecated and will raise in a future version. Explicitly cast the strings to a boolean dtype before operating instead.
#   print(orders[(orders['지역'] == '서울') | orders['지역'] == '부산'])

# %% [markdown]
# ## 5. 값 수정
# 1. 결제상태가 취소인 행의 수량을 0으로 수정하시오.
# 2. 지역이 결측치인 행의 지역을 '미상'으로 수정하시오.

# %%
orders.loc[orders['결제상태'] == '취소','수량'] = 0
orders.loc[orders['지역'].isna(), '지역'] = '미상'
orders
# Out:
#    주문번호        주문일자  고객명  지역 카테고리  상품명    수량       단가 결제상태
# 0  O001  2026-01-03  김철수  서울   전자  노트북   1.0  1500000   완료
# 1  O002  2026-01-05  이영희  부산   식품   사과  10.0     3000   완료
# 2  O003  2026-01-05  박민수  서울   전자  마우스   2.0    25000   완료
# 3  O004  2026-01-08  최지영  대전   패션   자켓   0.0   120000   취소
# 4  O005  2026-01-10  정다은  미상   식품   우유   NaN     2500   완료
# 5  O006  2026-01-12  홍길동  부산   전자  키보드   1.0    50000   완료
# 6  O006  2026-01-12  홍길동  부산   전자  키보드   1.0    50000   완료
# 7  O008  2026-01-15  강민호  서울   패션  운동화   2.0    90000   완료

# %% [markdown]
# ## 6. 파생 열 추가
# 총액 열을 추가하시오. 총액 = 수량 * 단가

# %%
orders['총액'] = orders['수량'] * orders['단가']  
orders
# Out:
#    주문번호        주문일자  고객명  지역 카테고리  상품명    수량       단가 결제상태         총액
# 0  O001  2026-01-03  김철수  서울   전자  노트북   1.0  1500000   완료  1500000.0
# 1  O002  2026-01-05  이영희  부산   식품   사과  10.0     3000   완료    30000.0
# 2  O003  2026-01-05  박민수  서울   전자  마우스   2.0    25000   완료    50000.0
# 3  O004  2026-01-08  최지영  대전   패션   자켓   0.0   120000   취소        0.0
# 4  O005  2026-01-10  정다은  미상   식품   우유   NaN     2500   완료        NaN
# 5  O006  2026-01-12  홍길동  부산   전자  키보드   1.0    50000   완료    50000.0
# 6  O006  2026-01-12  홍길동  부산   전자  키보드   1.0    50000   완료    50000.0
# 7  O008  2026-01-15  강민호  서울   패션  운동화   2.0    90000   완료   180000.0

# %% [markdown]
# ## 7. 입출력
# 1. 현재 DataFrame을 orders_raw.csv로 저장하시오. 인덱스는 저장하지 마시오.
# 2. 저장한 파일을 다시 읽어 orders_csv 변수에 담고 상위 2행을 확인하시오.

# %%
orders.to_csv('orders_raw.csv', index=False, encoding='utf-8-sig')
orders_csv=pd.read_csv('orders_raw.csv')
orders_csv.head(2)
# Out:
#    주문번호        주문일자  고객명  지역 카테고리  상품명    수량       단가 결제상태         총액
# 0  O001  2026-01-03  김철수  서울   전자  노트북   1.0  1500000   완료  1500000.0
# 1  O002  2026-01-05  이영희  부산   식품   사과  10.0     3000   완료    30000.0

# %% [markdown]
# ## 8. 결측값 확인
# 1. 열별 결측값 개수를 확인하시오.
# 2. 결측값이 하나라도 있는 행만 조회하시오.

# %%
print(orders.isna().sum()) 
display(orders[orders.isna().any(axis=1)])
# Out:
# 주문번호    0
# 주문일자    0
# 고객명     0
# 지역      0
# 카테고리    0
# 상품명     0
# 수량      1
# 단가      0
# 결제상태    0
# 총액      1
# dtype: int64
#    주문번호        주문일자  고객명  지역 카테고리 상품명  수량    단가 결제상태  총액
# 4  O005  2026-01-10  정다은  미상   식품  우유 NaN  2500   완료 NaN

# %% [markdown]
# ## 9. 결측값 처리
# 1. 수량 결측치는 1로 채우시오.
# 2. 지역 결측치는 '미상'으로 채우시오. 처리 결과를 orders_clean 변수에 저장하시오.

# %%
orders_clean = orders.fillna({
    '수량' : 1,
    '지역' : '미상'
})
orders_clean
# Out:
#    주문번호        주문일자  고객명  지역 카테고리  상품명    수량       단가 결제상태         총액
# 0  O001  2026-01-03  김철수  서울   전자  노트북   1.0  1500000   완료  1500000.0
# 1  O002  2026-01-05  이영희  부산   식품   사과  10.0     3000   완료    30000.0
# 2  O003  2026-01-05  박민수  서울   전자  마우스   2.0    25000   완료    50000.0
# 3  O004  2026-01-08  최지영  대전   패션   자켓   0.0   120000   취소        0.0
# 4  O005  2026-01-10  정다은  미상   식품   우유   1.0     2500   완료        NaN
# 5  O006  2026-01-12  홍길동  부산   전자  키보드   1.0    50000   완료    50000.0
# 6  O006  2026-01-12  홍길동  부산   전자  키보드   1.0    50000   완료    50000.0
# 7  O008  2026-01-15  강민호  서울   패션  운동화   2.0    90000   완료   180000.0

# %% [markdown]
# ## 10. 중복값 처리
# 1. 중복 행 개수를 확인하시오.
# 2. 중복 행을 제거한 결과를 orders_unique 변수에 저장하시오.

# %%
orders.duplicated().sum()  
# 정답 : orders_clean.duplicated().sum()
orders_unique = orders.drop_duplicates()
# 정답 : orders_unique = orders_clean.drop_duplicates()
orders_unique

# %% [markdown]
# ## 11. 정렬
# - orders_unique를 기준으로
# 1. 단가 내림차순 정렬
# 2. 카테고리 오름차순, 단가 내림차순 정렬 을 수행하시오.

# %%
orders_unique.sort_values('단가', ascending=False) 
orders_unique.sort_values(['카테고리','단가'], ascending=[True, False])
# Out:
#    주문번호        주문일자  고객명  지역 카테고리  상품명    수량       단가 결제상태         총액
# 1  O002  2026-01-05  이영희  부산   식품   사과  10.0     3000   완료    30000.0
# 4  O005  2026-01-10  정다은  미상   식품   우유   NaN     2500   완료        NaN
# 0  O001  2026-01-03  김철수  서울   전자  노트북   1.0  1500000   완료  1500000.0
# 5  O006  2026-01-12  홍길동  부산   전자  키보드   1.0    50000   완료    50000.0
# 2  O003  2026-01-05  박민수  서울   전자  마우스   2.0    25000   완료    50000.0
# 3  O004  2026-01-08  최지영  대전   패션   자켓   0.0   120000   취소        0.0
# 7  O008  2026-01-15  강민호  서울   패션  운동화   2.0    90000   완료   180000.0

# %% [markdown]
# # 12. 타입 변환
# - orders_unique의 주문일자 열을 datetime으로 변환하시오.

# %%
orders_unique['주문일자'] = pd.to_datetime(orders_unique['주문일자'])

# %% [markdown]
# ## 13. 최종 확인
# 전처리가 끝난 orders_unique에서 필요한 열만 골라 final_orders 변수에 저장하시오. 선택 열: 주문일자, 고객명, 지역, 카테고리, 상품명, 수량, 단가, 총액, 결제상태

# %%
final_orders = orders_unique[['주문일자', '고객명', '지역', '카테고리', '상품명', '수량', '단가', '총액', '결제상태']]
final_orders
# Out:
#         주문일자  고객명  지역 카테고리  상품명    수량       단가         총액 결제상태
# 0 2026-01-03  김철수  서울   전자  노트북   1.0  1500000  1500000.0   완료
# 1 2026-01-05  이영희  부산   식품   사과  10.0     3000    30000.0   완료
# 2 2026-01-05  박민수  서울   전자  마우스   2.0    25000    50000.0   완료
# 3 2026-01-08  최지영  대전   패션   자켓   0.0   120000        0.0   취소
# 4 2026-01-10  정다은  미상   식품   우유   NaN     2500        NaN   완료
# 5 2026-01-12  홍길동  부산   전자  키보드   1.0    50000    50000.0   완료
# 7 2026-01-15  강민호  서울   패션  운동화   2.0    90000   180000.0   완료
